# %% [markdown]
# <a href="https://colab.research.google.com/github/Firdous-Bin-Ismail/NLP_With_ML/blob/main/NLP_with_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('train.txt', sep =';', header= None, names=['Text','Emotion'])

# %%
df.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df['Emotion'].unique()
# Out:
# array(['sadness', 'anger', 'love', 'surprise', 'fear', 'joy'],
#       dtype=object)

# %%
Label = LabelEncoder()
df['Emotion'] = Label.fit_transform(df['Emotion'])

# %%
df.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated        4
# 1  i can go from feeling so hopeless to so damned...        4
# 2   im grabbing a minute to post i feel greedy wrong        0
# 3  i am ever feeling nostalgic about the fireplac...        3
# 4                               i am feeling grouchy        0

# %%
df['Text'] = df['Text'].apply(lambda x: x.lower())

# %%
import string

# %%
def rmv_punc(txt):
  return txt.translate(str.maketrans('','', string.punctuation))

# %%
df['Text'] = df['Text'].apply(rmv_punc)

# %%
def rmv_nmbr(txt):
  new = ""
  for i in txt:
    if not i.isdigit():
        new = new+i
  return new

# %%
df ['Text'] = df['Text'].apply(rmv_nmbr)

# %%
def rmv_emo(txt):
  new = ""
  for i in txt:
    if i.isascii():
        new = new+i
  return new

# %%
df['Text'] = df['Text'].apply(rmv_emo)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def rmv_stopwords(txt):
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(txt)
  filtered_word = []
  for w in word_tokens:
    if w not in stop_words:
      filtered_word.append(w)
  return ' '.join(filtered_word)
  #return filtered_word

# %%
df ['Text'] = df['Text'].apply(rmv_stopwords)

# %%
df.head()
# Out:
#                                                 Text  Emotion
# 0                              didnt feel humiliated        4
# 1  go feeling hopeless damned hopeful around some...        4
# 2          im grabbing minute post feel greedy wrong        0
# 3  ever feeling nostalgic fireplace know still pr...        3
# 4                                    feeling grouchy        0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Text'], df['Emotion'], test_size=0.2, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
Bow = CountVectorizer()
X_train_Bow = Bow.fit_transform(X_train)
X_test_Bow = Bow.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
NBmodel = MultinomialNB()
NBmodel.fit(X_train_Bow, y_train)
# Out:
# MultinomialNB()

# %%
Pred = NBmodel.predict(X_test_Bow)

# %%
Accur = accuracy_score(y_test, Pred)
print(Accur)
# Out:
# 0.7678125

# %%
Tf = TfidfVectorizer()
X_train_Tf = Tf.fit_transform(X_train)
X_test_Tf = Tf.transform(X_test)

# %%
NBmodel = MultinomialNB()
NBmodel.fit(X_train_Tf, y_train)
# Out:
# MultinomialNB()

# %%
Pred = NBmodel.predict(X_test_Tf)

# %%
Accura = accuracy_score(y_test, Pred)
print(Accura)
# Out:
# 0.6609375

# %%
from sklearn.linear_model import LogisticRegression

# %%
LG = LogisticRegression(max_iter=1000)
LG.fit(X_train_Tf, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
LG_pred = LG.predict(X_test_Tf)

# %%
Accuracy = accuracy_score(y_test, LG_pred)
print(Accuracy)
# Out:
# 0.8615625
